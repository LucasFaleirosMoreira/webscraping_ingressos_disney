# %%
import pandas as pd
from openpyxl import load_workbook

# %%
df_webscrap = pd.read_excel("Disney personal valores 11.08.2025.xlsx")
df_basico = pd.read_excel("Basico.xlsx")
df_hopper = pd.read_excel("Hopper.xlsx")
df_hopper_plus = pd.read_excel("Hopper Plus.xlsx")

# %%
df_webscrap.groupby('Nome Tickets').size()
# Out:
# Nome Tickets
# 1-day disney's animal kingdom theme park ticket                    446
# 1-day disney's hollywood studios theme park ticket                 446
# 1-day epcot theme park ticket                                      446
# 1-day magic kingdom theme park ticket                              446
# 1-day theme park ticket with park hopper option                    446
#                                                                   ...
# PROMO 8-day theme park ticket with water park and sports option     40
# PROMO 9-day theme park base ticket                                  40
# PROMO 9-day theme park ticket with park hopper option               40
# PROMO 9-day theme park ticket with park hopper plus option          40
# PROMO 9-day theme park ticket with water park and sports option     40
# Length: 62, dtype: int64

# %%
days_2 = df_webscrap[
    df_webscrap["Nome Tickets"].str.contains("2-day theme park", case=False, na=False) &
    ~df_webscrap["Nome Tickets"].str.contains("promo", case=False, na=False) &
    ~df_webscrap["Nome Tickets"].str.contains("water park and sports option", case=False, na=False)
]

days_3 = df_webscrap[
    df_webscrap["Nome Tickets"].str.contains("3-day theme park", case=False, na=False) &
    ~df_webscrap["Nome Tickets"].str.contains("promo", case=False, na=False) &
    ~df_webscrap["Nome Tickets"].str.contains("water park and sports option", case=False, na=False)
]

days_4 = df_webscrap[
    df_webscrap["Nome Tickets"].str.contains("4-day theme park", case=False, na=False) &
    ~df_webscrap["Nome Tickets"].str.contains("promo", case=False, na=False) &
    ~df_webscrap["Nome Tickets"].str.contains("water park and sports option", case=False, na=False)
]


days_5 = df_webscrap[
    df_webscrap["Nome Tickets"].str.contains("5-day theme park", case=False, na=False) &
    ~df_webscrap["Nome Tickets"].str.contains("promo", case=False, na=False) &
    ~df_webscrap["Nome Tickets"].str.contains("water park and sports option", case=False, na=False)
]

days_6 = df_webscrap[
    df_webscrap["Nome Tickets"].str.contains("6-day theme park", case=False, na=False) &
    ~df_webscrap["Nome Tickets"].str.contains("promo", case=False, na=False) &
    ~df_webscrap["Nome Tickets"].str.contains("water park and sports option", case=False, na=False)
]

days_7 = df_webscrap[
    df_webscrap["Nome Tickets"].str.contains("7-day theme park", case=False, na=False) &
    ~df_webscrap["Nome Tickets"].str.contains("promo", case=False, na=False) &
    ~df_webscrap["Nome Tickets"].str.contains("water park and sports option", case=False, na=False)
]

days_8 = df_webscrap[
    df_webscrap["Nome Tickets"].str.contains("8-day theme park", case=False, na=False) &
    ~df_webscrap["Nome Tickets"].str.contains("promo", case=False, na=False) &
    ~df_webscrap["Nome Tickets"].str.contains("water park and sports option", case=False, na=False)
]

days_9 = df_webscrap[
    df_webscrap["Nome Tickets"].str.contains("9-day theme park", case=False, na=False) &
    ~df_webscrap["Nome Tickets"].str.contains("promo", case=False, na=False) &
    ~df_webscrap["Nome Tickets"].str.contains("water park and sports option", case=False, na=False)
]

days_10 = df_webscrap[
    df_webscrap["Nome Tickets"].str.contains("10-day theme park", case=False, na=False) &
    ~df_webscrap["Nome Tickets"].str.contains("promo", case=False, na=False) &
    ~df_webscrap["Nome Tickets"].str.contains("water park and sports option", case=False, na=False)
]

promo_6_days = df_webscrap[df_webscrap["Nome Tickets"].str.contains("PROMO 6-", case=False, na=False)]

promo_7_days = df_webscrap[df_webscrap["Nome Tickets"].str.contains("PROMO 7-", case=False, na=False)]

promo_8_days = df_webscrap[df_webscrap["Nome Tickets"].str.contains("PROMO 8-", case=False, na=False)]

promo_9_days = df_webscrap[df_webscrap["Nome Tickets"].str.contains("PROMO 9-", case=False, na=False)]

promo_10_days = df_webscrap[df_webscrap["Nome Tickets"].str.contains("PROMO 10-", case=False, na=False)]

# %%
days_10.groupby("Data Ingresso").size()
# Out:
# Data Ingresso
# 01/01/2026    4
# 01/02/2026    4
# 01/03/2026    4
# 01/04/2026    4
# 01/05/2026    4
#              ..
# 31/08/2025    4
# 31/08/2026    4
# 31/10/2025    4
# 31/10/2026    4
# 31/12/2025    4
# Length: 446, dtype: int64

# %%
days_2.to_excel('teste.xlsx', index=False)

# %%
principal = "teste.xlsx"
    
with pd.ExcelWriter(principal, engine='openpyxl', mode='a') as writer:
    days_2.to_excel(writer, sheet_name='2-days', index=False)

with pd.ExcelWriter(principal, engine='openpyxl', mode='a') as writer:
    days_3.to_excel(writer, sheet_name='3-days', index=False)

with pd.ExcelWriter(principal, engine='openpyxl', mode='a') as writer:
    days_4.to_excel(writer, sheet_name='4-days', index=False)

with pd.ExcelWriter(principal, engine='openpyxl', mode='a') as writer:
    days_5.to_excel(writer, sheet_name='5-days', index=False)

with pd.ExcelWriter(principal, engine='openpyxl', mode='a') as writer:
    days_6.to_excel(writer, sheet_name='6-days', index=False)

with pd.ExcelWriter(principal, engine='openpyxl', mode='a') as writer:
    days_7.to_excel(writer, sheet_name='7-days', index=False)

with pd.ExcelWriter(principal, engine='openpyxl', mode='a') as writer:
    days_8.to_excel(writer, sheet_name='8-days', index=False)

with pd.ExcelWriter(principal, engine='openpyxl', mode='a') as writer:
    days_9.to_excel(writer, sheet_name='9-days', index=False)

with pd.ExcelWriter(principal, engine='openpyxl', mode='a') as writer:
    days_10.to_excel(writer, sheet_name='10-days', index=False)

with pd.ExcelWriter(principal, engine='openpyxl', mode='a') as writer:
    promo_6_days.to_excel(writer, sheet_name='PROMO 6-days', index=False)

with pd.ExcelWriter(principal, engine='openpyxl', mode='a') as writer:
    promo_7_days.to_excel(writer, sheet_name='PROMO 7-days', index=False)

with pd.ExcelWriter(principal, engine='openpyxl', mode='a') as writer:
    promo_8_days.to_excel(writer, sheet_name='PROMO 8-days', index=False)

with pd.ExcelWriter(principal, engine='openpyxl', mode='a') as writer:
    promo_9_days.to_excel(writer, sheet_name='PROMO 9-days', index=False)

with pd.ExcelWriter(principal, engine='openpyxl', mode='a') as writer:
    promo_10_days.to_excel(writer, sheet_name='PROMO 10-days', index=False)
